# %%
from decisionTree import get_acc, make_decisionTree, decisionTreeAnalysis, plot_acc
from get_features import get_morphology, get_all_features, get_labels
import pandas as pd
from sklearn.ensemble import RandomForestClassifier


labels = get_labels()
morphology_features = get_morphology()
full_dataframe = pd.merge(morphology_features, labels, left_index=True, right_index=True)

X = full_dataframe.drop(labels.columns, axis=1)
Y = full_dataframe["dendrite_type"]
max_leaf_nodes = 4

labelName = "dendrite_type"
classifiers = ["RandomForest", "DecisionTree"]
max_nodes = 24
# Out:
# c:\Users\lynnh\OneDrive\research\cell_classification\scripts\get_features.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe_labels['dendrite_type_number'] = le1.transform(filtered_dataframe_labels['dendrite_type'])
# c:\Users\lynnh\OneDrive\research\cell_classification\scripts\get_features.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe_labels['structure_layer_name_number'] = le2.transform(filtered_dataframe_labels['structure_layer_name'])
# ...

# %%
featureType = "morphology"
plot_acc(X, Y, labelName, classifiers, featureType, max_nodes)
# Out:
# {'RandomForest': [0.8461538461538461, 0.8692307692307693, 0.8788461538461538, 0.8884615384615384, 0.8942307692307693, 0.9134615384615384, 0.925, 0.9288461538461539, 0.9365384615384615, 0.9423076923076923, 0.948076923076923, 0.9519230769230769, 0.9576923076923077, 0.9653846153846154, 0.9673076923076923, 0.9692307692307692, 0.9711538461538461, 0.9711538461538461, 0.9711538461538461, 0.9730769230769231, 0.9769230769230769, 0.9788461538461538], 'DecisionTree': [0.85, 0.875, 0.875, 0.8903846153846153, 0.9230769230769231, 0.925, 0.9326923076923077, 0.9365384615384615, 0.9461538461538461, 0.95, 0.9538461538461539, 0.9538461538461539, 0.9596153846153846, 0.9615384615384616, 0.9634615384615385, 0.9653846153846154, 0.9653846153846154, 0.9711538461538461, 0.9730769230769231, 0.975, 0.9769230769230769, 0.9788461538461538]} {'RandomForest': [0.8615384615384616, 0.8692307692307693, 0.8769230769230769, 0.8923076923076924, 0.8923076923076924, 0.8923076923076924, 0.8923076923076924, 0.915384615384615
# ...

# %%
Y = full_dataframe["species"]

labelName = "species"
featureType = "morphology"
plot_acc(X, Y, labelName, classifiers, featureType, max_nodes)
# Out:
# {'RandomForest': [0.9192307692307692, 0.9346153846153846, 0.9519230769230769, 0.9653846153846154, 0.9673076923076923, 0.9711538461538461, 0.9788461538461538, 0.9807692307692307, 0.9826923076923076, 0.9865384615384616, 0.9884615384615385, 0.9884615384615385, 0.9884615384615385, 0.9884615384615385, 0.9903846153846154, 0.9903846153846154, 0.9903846153846154, 0.9923076923076923, 0.9923076923076923, 0.9942307692307693, 0.9942307692307693, 0.9961538461538462], 'DecisionTree': [0.9153846153846154, 0.9653846153846154, 0.9730769230769231, 0.9769230769230769, 0.9769230769230769, 0.9826923076923076, 0.9846153846153847, 0.9865384615384616, 0.9865384615384616, 0.9884615384615385, 0.9884615384615385, 0.9923076923076923, 0.9923076923076923, 0.9942307692307693, 0.9942307692307693, 0.9961538461538462, 0.9961538461538462, 0.9980769230769231, 0.9980769230769231, 1.0, 1.0, 1.0]} {'RandomForest': [0.9230769230769231, 0.9307692307692308, 0.9384615384615385, 0.9384615384615385, 0.9461538461538461, 0.961538
# ...

# %%
Y = full_dataframe["processed_structure_layer_name"]

labelName = "layer_name"
featureType = "morphology"
plot_acc(X, Y, labelName, classifiers, featureType, max_nodes)
# Out:
# {'RandomForest': [0.4269230769230769, 0.45576923076923076, 0.5461538461538461, 0.5884615384615385, 0.6192307692307693, 0.6346153846153846, 0.6384615384615384, 0.65, 0.6615384615384615, 0.676923076923077, 0.6884615384615385, 0.7057692307692308, 0.7192307692307692, 0.7326923076923076, 0.7461538461538462, 0.7519230769230769, 0.7711538461538462, 0.775, 0.7826923076923077, 0.7846153846153846, 0.7923076923076923, 0.8076923076923077], 'DecisionTree': [0.4653846153846154, 0.49230769230769234, 0.5230769230769231, 0.5557692307692308, 0.5923076923076923, 0.5923076923076923, 0.5923076923076923, 0.6, 0.6057692307692307, 0.6134615384615385, 0.6230769230769231, 0.6307692307692307, 0.6365384615384615, 0.65, 0.6576923076923077, 0.6634615384615384, 0.6653846153846154, 0.6730769230769231, 0.6807692307692308, 0.6865384615384615, 0.698076923076923, 0.7038461538461539]} {'RandomForest': [0.3230769230769231, 0.36923076923076925, 0.5, 0.5538461538461539, 0.5769230769230769, 0.5769230769230769, 0.58461538461
# ...
