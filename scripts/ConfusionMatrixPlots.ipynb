# %% [markdown]
# 0. rerun the layer num 1

# %%
import pandas as pd
from get_features import get_dataframes, get_labels, get_morphology, get_all_features
from decisionTree import make_decisionTree, get_acc, plot_acc, decisionTreeAnalysis

labels = get_labels()
epys_features = get_dataframes()
morphology = get_morphology()
full_dataframe_ephys = pd.merge(epys_features, labels, left_index=True, right_index=True)
full_dataframe_morph = pd.merge(morphology, labels, left_index=True, right_index=True)

full_dataframe_both = pd.merge(epys_features, morphology, left_index=True, right_index=True)
full_dataframe_both = pd.merge(full_dataframe_both,  labels, left_index=True, right_index=True)

X = full_dataframe_ephys.drop(labels.columns, axis=1)


# plot accuracy using dendrite type feature
Y = full_dataframe_ephys["processed_structure_layer_name"]
labelName = "Layer Number"
classifiers = ["RandomForest", "DecisionTree"]
max_nodes = 30
featureType = "Electrophysiology"
plot_acc(X, Y, labelName, classifiers, featureType, max_nodes)
# Out:
# c:\Users\lynnh\OneDrive\research\cell_classification\scripts\get_features.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe_labels['dendrite_type_number'] = le1.transform(filtered_dataframe_labels['dendrite_type'])
# c:\Users\lynnh\OneDrive\research\cell_classification\scripts\get_features.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_dataframe_labels['structure_layer_name_number'] = le2.transform(filtered_dataframe_labels['structure_layer_name'])
# ...

# %%
max_nodes = 8
decisionTreeAnalysis(X, Y, labelName, classifiers[0], featureType, max_nodes = max_nodes)

# %%
make_decisionTree(X, Y, max_nodes, labelName, featureType)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 make_decisionTree(X, Y, max_nodes, labelName, featureType)
#
# File c:\Users\lynnh\OneDrive\research\cell_classification\scripts\decisionTree.py:24, in make_decisionTree(X, Y, max_leaf_nodes, label, featureType)
#      15 def make_decisionTree(X, Y, max_leaf_nodes, label, featureType):
#      16     """
#      17     creates a decision tree and fits to x and y train and plots the tree.
#      18
#    (...)     22         max_leaf_nodes (int): the max number of leaf nodes for the tree.
#      23     """
# ---> 24     fig, ax = plt.subplot()
#      25     X = X.to_numpy()
#      26     Y = Y.to_numpy()
#
# TypeError: cannot unpack non-iterable Axes object

# %% [markdown]
# 1. Split cells into human and mouse cells

# %% [markdown]
# 2. brain area by itself for each species

# %% [markdown]
# 3. for each species, run brain area X Layer num X dendrite type
